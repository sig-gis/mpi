# %% [markdown]
# This notebook tries to find commune codes and names of CFs as they are represented in DB23 (`ncdd_admin_database_25provinces__2023.xlsx` from Lok on 20231212).
#
# The focus is on the 36 CFs not programatically matched in `explore_DB23.ipynb` or manually matched. A GIS-assisted matching is used.

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely import wkt
from pathlib import Path
from itables import show

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.match_commune_CF_vs_DB23 import *

# %%
# paths
code_path = Path().absolute()
datafd_path = code_path.parent.parent / 'data'
intmd_outfd_path = code_path.parent.parent / 'output_intmd' / 'match_CF_DB23'

# %% [markdown]
# ## Read in data

# %% [markdown]
# ### CF data: 74 CFs whose previously matched CDB communes (if any) fail to find it a DB23 commune [for ChatGPT, aborted]
# CF communes and districts names matched to CDB ones
#
# a list of CDB villages in the commune each CF belongs to
#
# and more

# %%
CF_vlst_df = pd.read_csv(intmd_outfd_path / 'CF_w_match_helper_vill_tomatch.csv')

# %% [markdown]
# ### CF data: all CFs, incl. 36/74 CFs whose communes yet to be found in DB23 after auto and manual matching
#
# to be matched in GIS-assisted matching section

# %%
CF_df = pd.read_csv(intmd_outfd_path / 'CF_w_match_helper_vill_DB23_comm_autoJoined_matched.csv')

# %% [markdown]
# #### df to gdf

# %%
# Convert the 'geometry' column from WKT to geometrical objects
CF_df['geometry'] = CF_df['geometry'].apply(wkt.loads)

# Create a GeoDataFrame
CF_gdf = gpd.GeoDataFrame(CF_df, geometry='geometry')

# Set the coordinate reference system (CRS) to EPSG:3148
CF_gdf = CF_gdf.set_crs(epsg=3148)

# %% [markdown]
# ### Admin shapefiles associated with CDB socio-economic data, Lok sent 20230407

# %%
CDB_shp_fd_path = datafd_path / 'boundaries' / 'Cambodia_Admin-2015'

# %% [markdown]
# #### village points

# %%
# v_pt_gdf = gpd.read_file(CDB_shp_fd_path / 'Villages.shp')  # EPSG:32648

# %% [markdown]
# #### commune boundaries

# %%
c_bnd_gdf = gpd.read_file(CDB_shp_fd_path / 'Commune Boundary.shp')  # EPSG:32648

# %%
c_gdf = c_bnd_gdf.to_crs(CF_gdf.crs)

# %% [markdown]
# #### district boundaries

# %%
# d_bnd_gdf = gpd.read_file(CDB_shp_fd_path / 'District Boundary.shp')  # EPSG:32648

# %% [markdown]
# #### province boundaries

# %%
# p_bnd_gdf = gpd.read_file(CDB_shp_fd_path / 'Province Boundary.shp')  # EPSG:32648

# %% [markdown]
# ## Initial processing of DB23

# %% [markdown]
# ### Read in DB23 and stack all sheets vertically into `db_df`

# %%
DB23_path = datafd_path / 'other' / 'ncdd_admin_database_25provinces__2023.xlsx'
DB23_df_dic = pd.read_excel(DB23_path, sheet_name=None, header=2)  
# all sheets, key=sheet name, skip first 2 rows, make row 3 header

# %%
sht_name_lst = list(DB23_df_dic.keys())
db_prov_df_lst = [DB23_df_dic[sht] for sht in sht_name_lst]

# %%
db_df = pd.concat(db_prov_df_lst)

# %% [markdown]
# ## GIS-assisted matching

# %% [markdown]
# ### Extract 36 CFs whose communes to be matched

# %%
CF36_gdf = CF_gdf[CF_gdf.Code_Comm_DB23.isna()]  # 36 to be matched

# %% [markdown]
# ### Find their communes based on spatial join with commune boundaries

# %%
CF36_c_gdf = gpd.sjoin(
    CF36_gdf, 
    c_gdf[['COMM_CODE', 'COMM_NAME', 'geometry']], 
    how="left", 
    predicate='intersects'
)

# %%
CF36_c_gdf.rename({
    'index_right': 'index_shp', 
    'COMM_CODE': 'COMM_CODE_shp',
    'COMM_NAME': 'COMM_NAME_shp'
}, inplace=True)

# %%
CF36_c_gdf.shape  # some CFs intersect with multiple communes
# Out:
# (72, 58)

# %% [markdown]
# ### Get DB23 communes from commune boundaries spatially joined (Join codes from commune boundaries to codes in DB23)

# %%
CF36_c_gdf.COMM_CODE = CF36_c_gdf.COMM_CODE.astype(int)

# %%
CF36_w_DB23 = CF36_c_gdf.merge(
    db_df[['Code', 'Name (Latin)']],
    how='left',
    left_on='COMM_CODE',
    right_on='Code',
    indicator=True,
    validate='many_to_one'
)

# %%
CF36_w_DB23._merge.value_counts()
# Out:
# both          72
# left_only      0
# right_only     0
# Name: _merge, dtype: int64

# %%
# Confirm all names are the same / similar
CF36_w_DB23.loc[
    CF36_w_DB23.COMM_NAME != CF36_w_DB23['Name (Latin)'],
    ['COMM_NAME', 'Name (Latin)']
]
# Out:
#         COMM_NAME  Name (Latin)
# 14   Srae Sangkom  Srae Sangkum
# 16        Bu Chri      Pu Chrey
# 18    Ou Buon Leu    A Buon Leu
# 19        Bu Chri      Pu Chrey
# 20   Srae Sangkom  Srae Sangkum
# 22  Nang Khi Loek  Nang Khi Lik
# 24   Srae Sangkom  Srae Sangkum
# 33           Pate         Pa Te

# %%
CF36_w_DB23.head(2)
# Out:
#    Unnamed: 0  CF_Code  Code_Srok  Code_Khum  No_Village    CF_Name_En  \
# 0          14        0          0          0           0  Phnom Phneas
# 1          14        0          0          0           0  Phnom Phneas
#
#   CF_Name_Kh Villag_CDB CF_Name_Note Commune  ... Code_Comm_DB23 Commun_DB23  \
# 0    PñMPñas        NaN          NaN  Steung  ...            NaN         NaN
# 1    PñMPñas        NaN          NaN  Steung  ...            NaN         NaN
#
#                                     Commun_DB23_Note Commune_DB23_cln  \
# 0  not matched based on CommGis, not matched by h...              NaN
# 1  not matched based on CommGis, not matched by h...              NaN
#
#   index_right COMM_CODE COMM_NAME   Code Name (Latin) _merge
# 0         398     20107    Snoeng  20107       Snoeng   both
# 1         371     20701      Sdau  20701         Sdau   both
#
# [2 rows x 61 columns]

# %% [markdown]
# ### Fit CFs that intersect with multiple communes into one row

# %%
# Aggregate communes per CF
CF36ID_w_DB23CommLst = CF36_w_DB23.groupby(['UniqueID']).agg(
    {
        var: lambda x: ', '.join(x.astype(str)) for var in ['Code', 'Name (Latin)']
    }  
)
CF36ID_w_DB23CommLst.head(2)
# Out:
#                                             Code  \
# UniqueID
# 262               160607, 160602, 160104, 160801
# 269       160605, 160604, 160602, 160904, 160906
#
#                                        Name (Latin)
# UniqueID
# 262               L'ak, Pouy, Ta Lav, Ta Veaeng Leu
# 269       Ou Chum, Kalai, Pouy, Ka Choun, Kaoh Peak

# %%
# Enrich the 36 CFs with the concatenated village names and codes
CF36_w_DB23CommLst = CF36_gdf.merge(
    CF36ID_w_DB23CommLst,
    how='inner',
    on='UniqueID',
    validate='1:1'
)

# %%
CF36_w_DB23CommLst
# Out:
#     Unnamed: 0  CF_Code  Code_Srok  Code_Khum  No_Village  \
# 0           14        0          0          0           0
# 1          207        0          0          0           0
# 2          233        0          0          0           0
# 3          234        0          0          0           0
# 4          269        0          0          0           0
# 5          312        0          0          0           0
# 6          313        0          0          0           0
# 7          316        0          0          0           0
# 8          332        0          0          0           0
# 9          333        0          0          0           0
# 10         334        0          0          0           0
# 11         335        0          0          0           0
# 12         336        0          0          0           0
# 13         337        0          0          0           0
# 14         338        0          0          0           0
# 15         339        0          0          0           0
# 16         340        0          0          0           0
# 17         341        0          0          0           0
# 18         501        0          0          0           0
# 19         502        0          0          0           0
# 20         503        0          0          0           0
# 21         513        0          0          0           0
# 22         530   160621       1606          0           0
# 23         531   160620       1606          0           0
# 24         621        0          0          0           0
# 25         622        0          0          0           0
# 26         623        0          0          0           0
# 27         624        0          0          0           0
# 28         625        0          0          0           0
# 29         626        0          0          0           0
# 30         627        0          0          0           0
# 31         628        0          0          0           0
# 32         629        0          0          0           0
# 33         630        0          0          0           0
# 34         631        0          0          0           0
# 35         632        0          0          0           0
#
#                     CF_Name_En       CF_Name_Kh Villag_CDB CF_Name_Note  \
# 0                 Phnom Phneas          PñMPñas        NaN          NaN
# 1                  Phnom Reang          PñMraMg        NaN          NaN
# 2                 Phnom Konsat        PñMkUnstV        NaN          NaN
# 3                Phnom Toteung          PñMTTWg        NaN          NaN
# 4                  Chang Krang            c®gÁg        NaN          NaN
# 5                 Svay Chras 1        sVayRCH 1        NaN          NaN
# 6                 Svay Chras 2        sVayRCH 2        NaN          NaN
# 7                         O Da            GUrda        NaN          NaN
# 8                         CBPF              NaN        NaN          NaN
# 9                     Ou Nglav          guRGØav        NaN          NaN
# 10             Trapeang Khaerm       RtBaMgek¥m        NaN          NaN
# 11                    Tou Lung            TUlug        NaN          NaN
# 12            Maloel Kong Pros      m:aLWkgRbus        NaN          NaN
# 13                    Pu Chrey            BUéRC        NaN          NaN
# 14                Ou Chhul (b)           GUrQYl        NaN          NaN
# 15                  A Buon Leu           GbYnLW        NaN          NaN
# 16                 Nglav Krach        køavRkac;        NaN          NaN
# 17                 Phum Puchry        puMIbuÉrc        NaN          NaN
# 18                       Rokat             rkat        NaN          NaN
# 19               Phum Angkrong        PUmiGRgÁg        NaN          NaN
# 20                         Say              say        NaN          NaN
# 21                   Phum Pril         PUmiRBil        NaN          NaN
# 22                      Yakpoy           y:akBy        NaN          NaN
# 23                    Yaka Old        y:akkaGUl        NaN          NaN
# 24                    Moha Sei            mhasI        NaN          NaN
# 25                    Ou Tavam        GUrtav:am        NaN          NaN
# 26     Preah Sbok Chrak Tamann  RBHs,kRcktaman;        NaN          NaN
# 27                 Ream Andeuk        ramGeNþIk        NaN          NaN
# 28                     Kampeng            kMEBg        NaN          NaN
# 29                   Kok Prech         eKaKRBic        NaN          NaN
# 30  Trapeang Thom Khang Tboung  RtBaMgFMxagt,Úg        NaN          NaN
# 31                Chros Phaaok       eRCaHep¥ak        NaN          NaN
# 32                  Payong Kao       )ay:g;ekar        NaN          NaN
# 33                    Samraong           sMerag        NaN          NaN
# 34                        Kous              KUs        NaN          NaN
# 35                     Tramkok          RtaMkk;        NaN          NaN
#
#         Commune  ... Commune_cln Village VillGis CommGis Code_Comm_DB23  \
# 0        Steung  ...         NaN     NaN     NaN   -9999            NaN
# 1           NaN  ...         NaN     NaN     NaN   -9999            NaN
# 2        Konsat  ...         NaN     NaN     NaN   -9999            NaN
# 3    Steung Keo  ...         NaN     NaN     NaN   -9999            NaN
# 4   Chang Krang  ...         NaN     NaN     NaN   -9999            NaN
# 5    Svay Chras  ...         NaN     NaN     NaN   -9999            NaN
# 6    Svay Chras  ...         NaN     NaN     NaN   -9999            NaN
# 7   Chang Krang  ...         NaN     NaN     NaN   -9999            NaN
# 8           NaN  ...         NaN     NaN     NaN   -9999            NaN
# 9           NaN  ...         NaN     NaN     NaN   -9999            NaN
# 10          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 11          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 12          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 13          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 14          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 15          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 16          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 17          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 18          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 19          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 20          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 21      Borkham  ...         NaN     NaN     NaN   -9999            NaN
# 22      Yakapoy  ...         NaN     NaN     NaN   -9999            NaN
# 23      Yakapoy  ...         NaN     NaN     NaN   -9999            NaN
# 24          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 25          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 26          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 27          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 28          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 29          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 30          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 31          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 32          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 33          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 34          NaN  ...         NaN     NaN     NaN   -9999            NaN
# 35          NaN  ...         NaN     NaN     NaN   -9999            NaN
#
#    Commun_DB23                                   Commun_DB23_Note  \
# 0          NaN  not matched based on CommGis, not matched by h...
# 1          NaN  not matched based on CommGis, not matched by h...
# 2          NaN  not matched based on CommGis, not matched by h...
# 3          NaN  not matched based on CommGis, not matched by h...
# 4          NaN  not matched based on CommGis, not matched by h...
# 5          NaN  not matched based on CommGis, not matched by h...
# 6          NaN  not matched based on CommGis, not matched by h...
# 7          NaN  not matched based on CommGis, not matched by h...
# 8          NaN  not matched based on CommGis, not matched by h...
# 9          NaN  not matched based on CommGis, not matched by h...
# 10         NaN  not matched based on CommGis, not matched by h...
# 11         NaN  not matched based on CommGis, not matched by h...
# 12         NaN  not matched based on CommGis, not matched by h...
# 13         NaN  not matched based on CommGis, not matched by h...
# 14         NaN  not matched based on CommGis, not matched by h...
# 15         NaN  not matched based on CommGis, not matched by h...
# 16         NaN  not matched based on CommGis, not matched by h...
# 17         NaN  not matched based on CommGis, not matched by h...
# 18         NaN  not matched based on CommGis, not matched by h...
# 19         NaN  not matched based on CommGis, not matched by h...
# 20         NaN  not matched based on CommGis, not matched by h...
# 21         NaN  not matched based on CommGis, not matched by h...
# 22         NaN  not matched based on CommGis, not matched by h...
# 23         NaN  not matched based on CommGis, not matched by h...
# 24         NaN  not matched based on CommGis, not matched by h...
# 25         NaN  not matched based on CommGis, not matched by h...
# 26         NaN  not matched based on CommGis, not matched by h...
# 27         NaN  not matched based on CommGis, not matched by h...
# 28         NaN  not matched based on CommGis, not matched by h...
# 29         NaN  not matched based on CommGis, not matched by h...
# 30         NaN  not matched based on CommGis, not matched by h...
# 31         NaN  not matched based on CommGis, not matched by h...
# 32         NaN  not matched based on CommGis, not matched by h...
# 33         NaN  not matched based on CommGis, not matched by h...
# 34         NaN  not matched based on CommGis, not matched by h...
# 35         NaN  not matched based on CommGis, not matched by h...
#
#    Commune_DB23_cln                                    Code  \
# 0               NaN                            20107, 20701
# 1               NaN                                   60701
# 2               NaN                                   70708
# 3               NaN                                   70715
# 4               NaN                          100602, 100607
# 5               NaN                                  100505
# 6               NaN                          100104, 100505
# 7               NaN                          100603, 100602
# 8               NaN                          110104, 110105
# 9               NaN                          110206, 110205
# 10              NaN                                  110402
# 11              NaN                                  110401
# 12              NaN                                  110202
# 13              NaN                                  110402
# 14              NaN                  110206, 110205, 110201
# 15              NaN                          110204, 110206
# 16              NaN                                  110503
# 17              NaN                          110503, 110403
# 18              NaN                          150405, 150406
# 19              NaN                                  150407
# 20              NaN                                  150404
# 21              NaN                          160701, 160704
# 22              NaN          160607, 160602, 160104, 160801
# 23              NaN  160605, 160604, 160602, 160904, 160906
# 24              NaN          210411, 210405, 210408, 210402
# 25              NaN                                  210411
# 26              NaN                  210412, 210411, 210408
# 27              NaN                          210409, 210410
# 28              NaN          210409, 210404, 210410, 210406
# 29              NaN                  210404, 210410, 210406
# 30              NaN                          210910, 210915
# 31              NaN                          210411, 210405
# 32              NaN                  210405, 210408, 210402
# 33              NaN                          210903, 210910
# 34              NaN                          210913, 210903
# 35              NaN                                  210913
#
#                                          Name (Latin)
# 0                                        Snoeng, Sdau
# 1                                          Boeng Lvea
# 2                                           Koun Satv
# 3                                         Stueng Kaev
# 4                                  Changkrang, Sambok
# 5                                         Svay Chreah
# 6                         Kampong Damrei, Svay Chreah
# 7                                     Dar, Changkrang
# 8                              Srae Khtum, Srae Preah
# 9                              Srae Sangkum, Srae Huy
# 10                                           Pu Chrey
# 11                                          Krang Teh
# 12                                         A Buon Leu
# 13                                           Pu Chrey
# 14               Srae Sangkum, Srae Huy, Nang Khi Lik
# 15                            Sokh Sant, Srae Sangkum
# 16                                    Spean Mean Chey
# 17                        Spean Mean Chey, Srae Ampum
# 18                                    Rokat, Santreae
# 19                                           Samraong
# 20                                            Prongil
# 21                                    Bar Kham, Pa Te
# 22                  L'ak, Pouy, Ta Lav, Ta Veaeng Leu
# 23          Ou Chum, Kalai, Pouy, Ka Choun, Kaoh Peak
# 24  Saom, Kiri Chong Kaoh, Prey Ampok, Preah Bat C...
# 25                                               Saom
# 26                            Ta Ou, Saom, Prey Ampok
# 27                         Prey Rumdeng, Ream Andaeuk
# 28  Prey Rumdeng, Kampeaeng, Ream Andaeuk, Kouk Prech
# 29                Kampeaeng, Ream Andaeuk, Kouk Prech
# 30               Samraong, Trapeang Thum Khang Tboung
# 31                              Saom, Kiri Chong Kaoh
# 32  Kiri Chong Kaoh, Prey Ampok, Preah Bat Choan Chum
# 33                                      Kus, Samraong
# 34                                      Tram Kak, Kus
# 35                                           Tram Kak
#
# [36 rows x 57 columns]

# %% [markdown]
# ### Put the 36 CFs back to the 603 already matched

# %%
CF603_gdf = CF_gdf[~CF_gdf.Code_Comm_DB23.isna()].drop(columns='Commune_DB23_cln')

# %% [markdown]
# #### Align column names with the 603 CFs

# %%
CF603_gdf.columns[-4:]
# Out:
# Index(['CommGis', 'Code_Comm_DB23', 'Commun_DB23', 'Commun_DB23_Note'], dtype='object')

# %%
CF36_w_DB23CommLst.columns[-6:]
# Out:
# Index(['Code_Comm_DB23', 'Commun_DB23', 'Commun_DB23_Note', 'Commune_DB23_cln',
#        'Code', 'Name (Latin)'],
#       dtype='object')

# %%
CF36_w_DB23CommLst['Code_Comm_DB23'] = CF36_w_DB23CommLst['Code']
CF36_w_DB23CommLst['Commun_DB23'] = CF36_w_DB23CommLst['Name (Latin)']

# %% [markdown]
# note how the 36 are matched

# %%
CF36_w_DB23CommLst['Commun_DB23_Note'] = 'not matched based on CommGis, \
matched through codes of commune boundaries intersecting with the CF'

# %%
CF36_w_DB23CommLst.drop(columns=['Code', 'Name (Latin)', 'Commune_DB23_cln'], inplace=True)

# %% [markdown]
# #### Append 36 & 603

# %%
all_CF_gdf = pd.concat([CF603_gdf, CF36_w_DB23CommLst], ignore_index=True)
all_CF_gdf.shape
# Out:
# (639, 54)

# %% [markdown]
# ### Export

# %%
all_CF_gdf.drop(columns='Unnamed: 0', inplace=True)
all_CF_gdf
# Out:
#      CF_Code  Code_Srok  Code_Khum  No_Village  \
# 0      10301        103      10302           3
# 1      10405        104      10402           2
# 2      10403        104      10402           1
# 3      10402        104      10402           1
# 4      10404        104      10402           1
# ..       ...        ...        ...         ...
# 634        0          0          0           0
# 635        0          0          0           0
# 636        0          0          0           0
# 637        0          0          0           0
# 638        0          0          0           0
#
#                                 CF_Name_En                    CF_Name_Kh  \
# 0                             Kon Khleaeng                       kUnExøg
# 1                         Phnom Chuncheang                    PMñCBa¢aMg
# 2                     Trapeang Russei Lech                RtBaMgb¤sISlic
# 3    Kiri Kamnobtrorb Sinjkeut Chrorbthmei  KIrIkMNb;RTBüsIujkWtRCab;fµI
# 4                    Trapeang Russei Kaeut               RtBaMgb¤sISekIt
# ..                                     ...                           ...
# 634                           Chros Phaaok                    eRCaHep¥ak
# 635                             Payong Kao                    )ay:g;ekar
# 636                               Samraong                        sMerag
# 637                                   Kous                           KUs
# 638                                Tramkok                       RtaMkk;
#
#     Villag_CDB CF_Name_Note     Commune      Khum  ... Commune_matched  \
# 0          NaN          NaN    Poy Char  e)a:ycar  ...        Poy Char
# 1          NaN          NaN  Chub Veary   Cb;varI  ...      Chob Veari
# 2          NaN          NaN  Chub Veary   Cb;varI  ...      Chob Veari
# 3          NaN          NaN  Chub Veary   Cb;varI  ...      Chob Veari
# 4          NaN          NaN  Chub Veary   Cb;varI  ...      Chob Veari
# ..         ...          ...         ...       ...  ...             ...
# 634        NaN          NaN         NaN       NaN  ...             NaN
# 635        NaN          NaN         NaN       NaN  ...             NaN
# 636        NaN          NaN         NaN       NaN  ...             NaN
# 637        NaN          NaN         NaN       NaN  ...             NaN
# 638        NaN          NaN         NaN       NaN  ...             NaN
#
#      District_matched      District_cln Commune_cln  \
# 0                 NaN                na    poy char
# 1    Preah Netr Preah  preah netr preah  chob veari
# 2    Preah Netr Preah  preah netr preah  chob veari
# 3    Preah Netr Preah  preah netr preah  chob veari
# 4    Preah Netr Preah  preah netr preah  chob veari
# ..                ...               ...         ...
# 634               NaN               NaN         NaN
# 635               NaN               NaN         NaN
# 636               NaN               NaN         NaN
# 637               NaN               NaN         NaN
# 638               NaN               NaN         NaN
#
#                                                Village  \
# 0    Paoy Snuol\nPaoy Char\nTrapeang Thma Tboung\nT...
# 1    Chob\nRoul Chruk\nPrasat\nKrasang Thmei\nPrada...
# 2    Chob\nRoul Chruk\nPrasat\nKrasang Thmei\nPrada...
# 3    Chob\nRoul Chruk\nPrasat\nKrasang Thmei\nPrada...
# 4    Chob\nRoul Chruk\nPrasat\nKrasang Thmei\nPrada...
# ..                                                 ...
# 634                                                NaN
# 635                                                NaN
# 636                                                NaN
# 637                                                NaN
# 638                                                NaN
#
#                                                VillGis CommGis  \
# 0    1030201\n1030202\n1030203\n1030204\n1030205\n1...   10302
# 1    1040201\n1040202\n1040203\n1040204\n1040205\n1...   10402
# 2    1040201\n1040202\n1040203\n1040204\n1040205\n1...   10402
# 3    1040201\n1040202\n1040203\n1040204\n1040205\n1...   10402
# 4    1040201\n1040202\n1040203\n1040204\n1040205\n1...   10402
# ..                                                 ...     ...
# 634                                                NaN   -9999
# 635                                                NaN   -9999
# 636                                                NaN   -9999
# 637                                                NaN   -9999
# 638                                                NaN   -9999
#
#              Code_Comm_DB23  \
# 0                     10302
# 1                     10402
# 2                     10402
# 3                     10402
# 4                     10402
# ..                      ...
# 634          210411, 210405
# 635  210405, 210408, 210402
# 636          210903, 210910
# 637          210913, 210903
# 638                  210913
#
#                                            Commun_DB23  \
# 0                                             Poy Char
# 1                                            Chob Vari
# 2                                            Chob Vari
# 3                                            Chob Vari
# 4                                            Chob Vari
# ..                                                 ...
# 634                              Saom, Kiri Chong Kaoh
# 635  Kiri Chong Kaoh, Prey Ampok, Preah Bat Choan Chum
# 636                                      Kus, Samraong
# 637                                      Tram Kak, Kus
# 638                                           Tram Kak
#
#                                       Commun_DB23_Note
# 0                             matched based on CommGis
# 1                             matched based on CommGis
# 2                             matched based on CommGis
# 3                             matched based on CommGis
# 4                             matched based on CommGis
# ..                                                 ...
# 634  not matched based on CommGis, matched through ...
# 635  not matched based on CommGis, matched through ...
# 636  not matched based on CommGis, matched through ...
# 637  not matched based on CommGis, matched through ...
# 638  not matched based on CommGis, matched through ...
#
# [639 rows x 53 columns]

# %%
# all_CF_gdf.to_csv(
#     intmd_outfd_path / 'CF_w_match_helper_vill_DB23_comm_autoJoined_matchedAll.csv',
#     index=False
# )

# %% [markdown]
# ## ChatGPT [aborted]

# %% [markdown]
# #### Step 1: Attempting to match using Code_Srok and Code_Khum (of CF) against the commune codes in the reference dataset (DB23)

# %%
db_comm_df = db_df[db_df.Type == 'ឃុំ']

# %%
# Apply the matching function to the subset data
CF_vlst_df['Matched_Commune_Name'], CF_vlst_df['Matched_Commune_Code'] = zip(
    *CF_vlst_df.apply(
        lambda row: match_commune_by_codes(row, ref_data=db_comm_df), axis=1
    )
)

# %%
# Display the results of the matching
show(CF_vlst_df[
    ['Code_Srok', 'Code_Khum', 'Matched_Commune_Code', 'Commune', 'Matched_Commune_Name', 'UniqueID']
])

# %% [markdown]
# CF UniqueID 170 matched with uncertainty, CF 31, 41, 14, 359, 295, 300, 301 partially matched.
